# %% [markdown]
# <a href="https://colab.research.google.com/github/taeyeoniiiiiii/AI-assignment/blob/main/%5BAI2025_Assignment%5D_CIFAR10_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 Classification

# %% [markdown]
# ## Import Packages

# %%
import sys
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Preparation
# Use CIFAR10 handwriting dataset

# %%
cifar10 = tf.keras.datasets.cifar10

# %% [markdown]
# Prepare data for training

# %%
# train / test split
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# minmax normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# # Compile and Train neural network

# %% [markdown]
# ## CNN Modeling
# Create a convolutional neural network

# %% [markdown]
# ### Goal
#
# Improve the provided basic CNN model and achieve CIFAR-10 **test accuracy ≥ 75%**.

# %% [markdown]
# Modify the network architecture!

# %%
model = tf.keras.models.Sequential([

    # Convolutional layer. Learn 64 filters using a 3x3 kernel
    tf.keras.layers.Conv2D(
        64, (3, 3), activation="relu", padding="same", input_shape=(32, 32, 3)
    ),

    # Max-pooling layer, using 2x2 pool size
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Convolutional layer. Learn 128 filters using a 3x3 kernel
    tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    # Max-pooling layer, using 2x2 pool size
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Convolutional layer. Learn 246 filters using a 3x3 kernel
    tf.keras.layers.Conv2D(256, (3, 3), activation="relu",padding="same"),
    # Max-pooling layer, using 2x2 pool size
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Flatten units
    tf.keras.layers.Flatten(),

    # Add a hidden layer with dropout
    tf.keras.layers.Dense(1024, activation="relu"),
    tf.keras.layers.Dropout(0.4),

    # Add a hidden layer with dropout
    tf.keras.layers.Dense(1024, activation="relu"),
    tf.keras.layers.Dropout(0.4),

    # Add an output layer with output units for all 10 digits
    tf.keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# # Compile and Train neural network

# %%
model.compile(
     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.2875 - loss: 1.8925 - val_accuracy: 0.5402 - val_loss: 1.2553
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5285 - loss: 1.3054 - val_accuracy: 0.6233 - val_loss: 1.0511
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6023 - loss: 1.1198 - val_accuracy: 0.6439 - val_loss: 1.0159
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6466 - loss: 0.9995 - val_accuracy: 0.6543 - val_loss: 0.9810
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6670 - loss: 0.9434 - val_accuracy: 0.7210 - val_loss: 0.7939
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6963 - loss: 0.8633 - val_accuracy: 0.7293 - val_loss: 0.7832
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7081 - loss: 0.8283 - val_accuracy: 0.7393 - val_loss: 0.7593
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7192 - loss: 0.7898 - val_accuracy: 0.7468 - val_loss: 0.7352
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7320 - loss: 0.7568 - val_accuracy: 0.7539 - val_loss: 0.7224
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7488 - loss: 0.7171 - val_accuracy: 0.7542 - val_loss: 0.7113
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7597 - loss: 0.6837 - val_accuracy: 0.7476 - val_loss: 0.7296
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7643 - loss: 0.6718 - val_accuracy: 0.7398 - val_loss: 0.7507
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7635 - loss: 0.6726 - val_accuracy: 0.7678 - val_loss: 0.6846
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7764 - loss: 0.6372 - val_accuracy: 0.7702 - val_loss: 0.6716
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7810 - loss: 0.6239 - val_accuracy: 0.7637 - val_loss: 0.7001
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7876 - loss: 0.6071 - val_accuracy: 0.7678 - val_loss: 0.6743
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7906 - loss: 0.5914 - val_accuracy: 0.7704 - val_loss: 0.6727
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7951 - loss: 0.5817 - val_accuracy: 0.7764 - val_loss: 0.6525
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8025 - loss: 0.5615 - val_accuracy: 0.7760 - val_loss: 0.6561
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8014 - loss: 0.5607 - val_accuracy: 0.7790 - val_loss: 0.6529
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8102 - loss: 0.5430 - val_accuracy: 0.7743 - val_loss: 0.6742
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8112 - loss: 0.5381 - val_accuracy: 0.7659 - val_loss: 0.6728
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8158 - loss: 0.5255 - val_accuracy: 0.7672 - val_loss: 0.6765
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8162 - loss: 0.5187 - val_accuracy: 0.7883 - val_loss: 0.6253
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8258 - loss: 0.5017 - val_accuracy: 0.7820 - val_loss: 0.6404
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8274 - loss: 0.4968 - val_accuracy: 0.7888 - val_loss: 0.6374
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8327 - loss: 0.4851 - val_accuracy: 0.7866 - val_loss: 0.6259
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8315 - loss: 0.4870 - val_accuracy: 0.7839 - val_loss: 0.6446
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8293 - loss: 0.4917 - val_accuracy: 0.7867 - val_loss: 0.6299
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8390 - loss: 0.4670 - val_accuracy: 0.7921 - val_loss: 0.6217

# %% [markdown]
# ## Evaluate neural network performance

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.7835 - loss: 0.6407
# [0.6406850218772888, 0.7835000157356262]

# %%
prob = model.predict(x_test[0:40], verbose=0)
pred = tf.argmax(prob, axis=1)

fig = plt.figure(figsize=(12, 18))

for i in range(40):
    ax = fig.add_subplot(9, 5, i + 1)
    ax.set_xticks([])
    ax.set_yticks([])
    string = r'$\hat{y}$'
    ax.set_title(f'$y$:{tf.argmax(y_test[i])}, {string}:{pred[i].numpy()}')
    ax.imshow(x_test[i])

ax_big = fig.add_subplot(9, 1, 9)
ax_big.set_title(
    f"GT: {tf.argmax(y_test[0]).numpy()}, Pred: {pred[0].numpy()}",
    fontsize=14
)
ax_big.set_xticks([])
ax_big.set_yticks([])

plt.tight_layout()
plt.show()

loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.7835000157356262

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.7835000157356262
